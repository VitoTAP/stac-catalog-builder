# %%
from pathlib import Path
import pprint

# run pip install -e . in the root directory to install this package
from stacbuilder import (
    build_collection,
    build_grouped_collections,
    list_asset_metadata,
    list_input_files,
    list_stac_items,
    load_collection,
    validate_collection,
)

# %%
# Collection configuration
catalog_version = "v0.1"
collection_config_path = Path("config-collection.json")

# Input Paths
tiff_input_path = Path("/data/users/Public/emile.sonneveld/ANIN/CROP_MASK/")
tiffs_glob = "*.tif"

# Output Paths
output_path = Path("results")
test_output_path = output_path / "test" / catalog_version
publish_output_path = "/data/users/Public/victor.verhaert/ANINStac/CROP_MASK"

# %%
# list input files
input_files = list_input_files(glob=tiffs_glob, input_dir=tiff_input_path, max_files=None)
print(f"Found {len(input_files)} input files. 5 first files:")
for i in input_files[:5]:
    print(i)
# Out:
# Found 12 input files. 5 first files:
# /data/users/Public/emile.sonneveld/ANIN/CROP_MASK/2020-01-01.tif
# /data/users/Public/emile.sonneveld/ANIN/CROP_MASK/2020-02-01.tif
# /data/users/Public/emile.sonneveld/ANIN/CROP_MASK/2020-03-01.tif
# /data/users/Public/emile.sonneveld/ANIN/CROP_MASK/2020-04-01.tif
# /data/users/Public/emile.sonneveld/ANIN/CROP_MASK/2020-05-01.tif

# %%
# list meta data
asset_metadata = list_asset_metadata(
    collection_config_path=collection_config_path, glob=tiffs_glob, input_dir=tiff_input_path, max_files=1
)
for k in asset_metadata:
    pprint.pprint(k.to_dict())
# Out:
# {'asset_id': '2020-01-01',
#  'asset_path': PosixPath('/data/users/Public/emile.sonneveld/ANIN/CROP_MASK/2020-01-01.tif'),
#  'asset_type': 'CROP_MASK',
#  'bbox_lat_lon': {'east': 32.89434523906337,
#                   'epsg': 4326,
#                   'north': -22.126488095214867,
#                   'south': -34.83184523806912,
#                   'west': 16.44791666756001},
#  'bbox_projected': {'east': 32.89434523906337,
#                     'epsg': 4326,
#                     'north': -22.126488095214867,
#                     'south': -34.83184523806912,
#                     'west': 16.44791666756001},
#  'collection_id': None,
#  'datetime': datetime.datetime(2020, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#  'end_datetime': datetime.datetime(2020, 1, 31, 23, 59, 59, tzinfo=datetime.timezone.utc),
#  'file_size': 1545313,
#  'geometry_lat_lon': <POLYGON ((16.448 -34.832, 16.448 -22.126, 32.894 -22.126, 32.894 -34.832, 1...>,
#  'href': '/data/users/Public/emile.sonneveld/ANIN/CROP_MASK/2020-01-01.tif',
#  'item_href': None,
#  'item_id': '2020-01-01',
#  'media_type': None,
#  'original_href': '/data/users/Public/emile.sonneveld/ANIN/CROP_MASK/2020-01-01.tif',
#  'raster_metadata': {'bands': [{'data_type': 'int16',
#                                 'index': 0,
#                                 'nodata': None}],
#                      'shape': (4269, 5526)},
#  'shape': (4269, 5526),
#  'start_datetime': datetime.datetime(2020, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#  'tags': {'AREA_OR_POINT': 'Area'},
#  'tile_id': None,
#  'title': None,
#  'transform': [0.0029761904762040103,
#                0.0,
#                16.44791666756001,
#                0.0,
#                -0.0029761904761897995,
#                -22.126488095214867]}

# %%
# list items
stac_items, failed_files = list_stac_items(
    collection_config_path=collection_config_path, glob=tiffs_glob, input_dir=tiff_input_path, max_files=10
)
print(f"Found {len(stac_items)} STAC items")
if failed_files:
    print(f"Failed files: {failed_files}")
# Out:
# Found 10 STAC items

# %%
print("First stac item:")
stac_items[0]
# Out:
# First stac item:
# <Item id=2020-01-01>

# %%
from shutil import rmtree

rmtree(test_output_path)

# %%
# build grouped collection
build_grouped_collections(
    collection_config_path=collection_config_path,
    glob=tiffs_glob,
    input_dir=tiff_input_path,
    output_dir=test_output_path,
)

# %%
# show collection
load_collection(collection_file=test_output_path / "collection.json")

# %%
# validate collection
validate_collection(
    collection_file=test_output_path / "collection.json",
)

# %% [markdown]
# ## Legacy
# Better to use grouped collections

# %%
# build collection
build_collection(
    collection_config_path=collection_config_path,
    glob=tiffs_glob,
    input_dir=tiff_input_path,
    output_dir=test_output_path,
)
