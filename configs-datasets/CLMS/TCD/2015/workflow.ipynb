# %%
from pathlib import Path
import pprint

# run pip install -e . in the root directory to install this package
from stacbuilder import (
    build_collection,
    list_asset_metadata,
    list_input_files,
    list_stac_items,
    validate_collection,
)

# %%
# Collection configuration
collection_config_path = Path("config-collection.json")

base_collection_path = Path("results/TREE_COVER_DENSITY_2015")

# Input Paths
tiff_input_path = base_collection_path / "resource"
tiffs_glob = "*.tif"

# Output Paths
output_path = base_collection_path / "new_collection"

# %%
# list input files
input_files = list_input_files(glob=tiffs_glob, input_dir=tiff_input_path, max_files=None)
print(f"Found {len(input_files)} input files. 5 first files:")
for i in input_files[:5]:
    print(i)
# Out:
# Found 27 input files. 5 first files:
# results\TREE_COVER_DENSITY_2015\resource\TCD_2015_020m_eu_03035_d05_E00N20.tif
# results\TREE_COVER_DENSITY_2015\resource\TCD_2015_020m_eu_03035_d05_E10N00.tif
# results\TREE_COVER_DENSITY_2015\resource\TCD_2015_020m_eu_03035_d05_E10N10.tif
# results\TREE_COVER_DENSITY_2015\resource\TCD_2015_020m_eu_03035_d05_E10N20.tif
# results\TREE_COVER_DENSITY_2015\resource\TCD_2015_020m_eu_03035_d05_E20N10.tif

# %%
# list meta data
asset_metadata = list_asset_metadata(
    collection_config_path=collection_config_path, glob=tiffs_glob, input_dir=tiff_input_path, max_files=1
)
for k in asset_metadata:
    pprint.pprint(k.to_dict())
# Out:
# WARNING | 2025-07-15 11:56:50,108 | The regex pattern does not have named groups: . Path parsing will be skipped and only fixed values will be used.
# {'asset_id': 'TCD_2015_020m_eu_03035_d05_E00N20',
#  'asset_path': WindowsPath('results/TREE_COVER_DENSITY_2015/resource/TCD_2015_020m_eu_03035_d05_E00N20.tif'),
#  'asset_type': 'TCD',
#  'bands': [{'data_type': 'uint8', 'index': 0, 'nodata': 250.0}],
#  'bbox_lat_lon': {'east': -26.92972247925556,
#                   'epsg': 4326,
#                   'north': 41.41220569498315,
#                   'south': 33.259010015522435,
#                   'west': -33.06646192143985},
#  'bbox_projected': {'east': 1000000.0,
#                     'epsg': 3035,
#                     'north': 3000000.0,
#                     'south': 2000000.0,
#                     'west': 900000.0},
#  'collection_id': None,
#  'datetime': datetime.datetime(2015, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#  'end_datetime': datetime.datetime(2015, 12, 31, 23, 59, 59, tzinfo=datetime.timezone.utc),
#  'file_size': 759017,
#  'geometry_lat_lon': <POLYGON ((-26.93 33.69, -32.017 41.412, -33.066 40.919, -27.915 33.259, -26...>,
#  'href': 'results\\TREE_COVER_DENSITY_2015\\resource\\TCD_2015_020m_eu_03035_d05_E00N20.tif',
#  'item_id': 'TCD_2015_020m_eu_03035_d05_E00N20',
#  'media_type': None,
#  'original_href': 'results\\TREE_COVER_DENSITY_2015\\resource\\TCD_2015_020m_eu_03035_d05_E00N20.tif',
#  'shape': [50000, 5000],
#  'start_datetime': datetime.datetime(2015, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#  'tags': {'AREA_OR_POINT': 'Area', 'DataType': 'Thematic'},
#  'tile_id': None,
#  'title': None,
#  'transform': [20.0, 0.0, 900000.0, 0.0, -20.0, 3000000.0]}

# %%
# list items
stac_items, failed_files = list_stac_items(
    collection_config_path=collection_config_path, glob=tiffs_glob, input_dir=tiff_input_path, max_files=10
)
print(f"Found {len(stac_items)} STAC items")
if failed_files:
    print(f"Failed files: {failed_files}")
# Out:
# WARNING | 2025-07-15 11:56:50,179 | The regex pattern does not have named groups: . Path parsing will be skipped and only fixed values will be used.
# INFO    | 2025-07-15 11:56:50,591 | PROGRESS: AssetMetadataPipeline.collect_stac_items: START: collect_stac_items
# INFO    | 2025-07-15 11:56:50,821 | PROGRESS: AssetMetadataPipeline._group_metadata_by_item_id: START: group_metadata_by_item_id
# INFO    | 2025-07-15 11:56:50,838 | PROGRESS: AssetMetadataPipeline._group_metadata_by_item_id: DONE: group_metadata_by_item_id
# INFO    | 2025-07-15 11:56:50,854 | PROGRESS: AssetMetadataPipeline.collect_stac_items: Converted 0 of 10 AssetMetadata to STAC Items (0.0%)
# INFO    | 2025-07-15 11:56:50,919 | PROGRESS: AssetMetadataPipeline.collect_stac_items: DONE: collect_stac_items
# Found 10 STAC items

# %%
print("First stac item:")
stac_items[0]
# Out:
# First stac item:
# <Item id=TCD_2015_020m_eu_03035_d05_E00N20>

# %%
# build collection
build_collection(
    collection_config_path=collection_config_path,
    glob=tiffs_glob,
    input_dir=tiff_input_path,
    output_dir=output_path,
)

# validate collection
validate_collection(
    collection_file=output_path / "collection.json",
)
# Out:
# WARNING | 2025-07-15 11:56:50,946 | The regex pattern does not have named groups: . Path parsing will be skipped and only fixed values will be used.
# INFO    | 2025-07-15 11:56:50,969 | PROGRESS: AssetMetadataPipeline.build_collection: START: build_collection
# INFO    | 2025-07-15 11:56:51,002 | PROGRESS: AssetMetadataPipeline.collect_stac_items: START: collect_stac_items
# INFO    | 2025-07-15 11:56:51,405 | PROGRESS: AssetMetadataPipeline._group_metadata_by_item_id: START: group_metadata_by_item_id
# INFO    | 2025-07-15 11:56:51,416 | PROGRESS: AssetMetadataPipeline._group_metadata_by_item_id: DONE: group_metadata_by_item_id
# INFO    | 2025-07-15 11:56:51,453 | PROGRESS: AssetMetadataPipeline.collect_stac_items: Converted 0 of 27 AssetMetadata to STAC Items (0.0%)
# INFO    | 2025-07-15 11:56:51,536 | PROGRESS: AssetMetadataPipeline.collect_stac_items: DONE: collect_stac_items
# INFO    | 2025-07-15 11:56:51,550 | PROGRESS: CollectionBuilder.create_empty_collection: START: create_empty_collection
# INFO    | 2025-07-15 11:56:51,562 | PROGRESS: CollectionBuilder.create_empty_collection: DONE: create_empty_collection
# INFO    | 2025-07-15 11:56:51,574 | PROGRESS: CollectionBuilder.add_items_to_collection: START: add_items_to_collection
# INFO    | 2025-07-15 11:56:51,589 | PROGRESS: CollectionBuilder.add_items_to_collection: updating collection extent
# INFO    | 2025-07-15 11:56:51,606 | PROGRESS: CollectionBuilder.add_items_to_collection: DONE: add_items_to_collection
# INFO    | 2025-07-15 11:56:51,621 | PROGRESS: CollectionBuilder.save_collection: START: Saving collection ...
# INFO    | 2025-07-15 11:56:51,651 | PROGRESS: CollectionBuilder.save_collection: DONE: Saving collection.
# INFO    | 2025-07-15 11:56:51,672 | PROGRESS: AssetMetadataPipeline.build_collection: DONE: build_collection
